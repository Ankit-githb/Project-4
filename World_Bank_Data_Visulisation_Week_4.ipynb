# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-githb/Project-4/blob/main/World_Bank_Data_Visulisation_Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Importing Libraries**

# %% [markdown]
# `pd.set_option` : Describes the behaviour of how floating-point numbers are shown within DataFrames in Pandas.

# %%
import numpy as np
import pandas as pd
import plotly.express as px
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# Refering to the file consisting of data in CSV

# %%
population_url='https://raw.githubusercontent.com/Ankit-githb/Project-4/main/country_population.csv'
population=pd.read_csv(population_url,encoding='unicode_escape')        # reads population dataset
fertility_url='https://raw.githubusercontent.com/Ankit-githb/Project-4/main/fertility_rate.csv'
fertility=pd.read_csv(fertility_url,encoding='unicode_escape')          # reads fertility rate dataset
metadata_url='https://raw.githubusercontent.com/Ankit-githb/Project-4/main/Metadata_Country.csv'
metadata=pd.read_csv(metadata_url,encoding='unicode_escape')            # reads life expectancy dataset
expectancy_url='https://raw.githubusercontent.com/Ankit-githb/Project-4/main/life_expectancy.csv'
expectancy=pd.read_csv(expectancy_url,encoding='unicode_escape')        # reads metadata dataset

# %% [markdown]
# ##**Cleaning & Processing Data Frame**

# %% [markdown]
# ###Population Data Frame

# %% [markdown]
# In order to clean and process `population` data frame
# *  Removing unnecessary column `['Indicator Name', 'Indicator Code']`
# *  Rename the column name whereever necessary. Here: `'ï»¿"Country Name"'` to `'Country Name'`
# *  Non-disclosed country `'Not Classified'`
# * Standardizing the column header `'_'`

# %%
columns_to_remove = ['Indicator Name', 'Indicator Code']                  # variable to store list of unnecessary columns
population = population.drop(columns=columns_to_remove)                   # dropping the unnecessary columns
population.rename(columns={'ï»¿"Country Name"': 'Country Name'}, inplace=True)    # renaming the column header
population = population[population['Country Name'] != 'Not classified']           # filtering out the specific row
population.columns=population.columns.str.lower().str.replace(' ','_')            # standardizing the column header
population
# Out:
#      country_name country_code        1960        1961        1962  \
# 0           Aruba          ABW    54211.00    55438.00    56225.00
# 1     Afghanistan          AFG  8996351.00  9166764.00  9345868.00
# 2          Angola          AGO  5643182.00  5753024.00  5866061.00
# 3         Albania          ALB  1608800.00  1659800.00  1711319.00
# 4         Andorra          AND    13411.00    14375.00    15370.00
# ..            ...          ...         ...         ...         ...
# 259        Kosovo          XKX   947000.00   966000.00   994000.00
# 260   Yemen, Rep.          YEM  5172135.00  5260501.00  5351799.00
# 261  South Africa          ZAF 17456855.00 17920673.00 18401608.00
# 262        Zambia          ZMB  3044846.00  3140264.00  3240587.00
# 263      Zimbabwe          ZWE  3747369.00  3870756.00  3999419.00
#
#            1963        1964        1965        1966        1967  ...  \
# 0      56695.00    57032.00    57360.00    57715.00    58055.00  ...
# 1    9533954.00  9731361.00  9938414.00 10152331.00 10372630.00  ...
# 2    5980417.00  6093321.00  6203299.00  6309770.00  6414995.00  ...
# 3    1762621.00  1814135.00  1864791.00  1914573.00  1965598.00  ...
# 4      16412.00    17469.00    18549.00    19647.00    20758.00  ...
# ..          ...         ...         ...         ...         ...  ...
# 259  1022000.00  1050000.00  1078000.00  1106000.00  1135000.00  ...
# 260  5446063.00  5543339.00  5643643.00  5748588.00  5858638.00  ...
# 261 18899275.00 19412975.00 19942303.00 20486439.00 21045785.00  ...
# 262  3345145.00  3452942.00  3563407.00  3676189.00  3791887.00  ...
# 263  4132756.00  4269863.00  4410212.00  4553433.00  4700041.00  ...
#
#            2007        2008        2009        2010        2011        2012  \
# 0     101220.00   101353.00   101453.00   101669.00   102053.00   102577.00
# 1   26616792.00 27294031.00 28004331.00 28803167.00 29708599.00 30696958.00
# 2   20997687.00 21759420.00 22549547.00 23369131.00 24218565.00 25096150.00
# 3    2970017.00  2947314.00  2927519.00  2913021.00  2905195.00  2900401.00
# 4      82683.00    83861.00    84462.00    84449.00    83751.00    82431.00
# ..          ...         ...         ...         ...         ...         ...
# 259  1733404.00  1747383.00  1761474.00  1775680.00  1791000.00  1805200.00
# 260 21751605.00 22356391.00 22974929.00 23606779.00 24252206.00 24909969.00
# 261 49887181.00 50412129.00 50970818.00 51584663.00 52263516.00 52998213.00
# 262 12725974.00 13082517.00 13456417.00 13850033.00 14264756.00 14699937.00
# 263 13329909.00 13558469.00 13810599.00 14086317.00 14386649.00 14710826.00
#
#            2013        2014        2015        2016
# 0     103187.00   103795.00   104341.00   104822.00
# 1   31731688.00 32758020.00 33736494.00 34656032.00
# 2   25998340.00 26920466.00 27859305.00 28813463.00
# 3    2895092.00  2889104.00  2880703.00  2876101.00
# 4      80788.00    79223.00    78014.00    77281.00
# ..          ...         ...         ...         ...
# 259  1824100.00  1821800.00  1801800.00  1816200.00
# 260 25576322.00 26246327.00 26916207.00 27584213.00
# 261 53767396.00 54539571.00 55291225.00 56015473.00
# 262 15153210.00 15620974.00 16100587.00 16591390.00
# 263 15054506.00 15411675.00 15777451.00 16150362.00
#
# [263 rows x 59 columns]
# Warning: Total number of columns (59) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['1960'].plot(kind='hist', bins=20, title='1960')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['1961'].plot(kind='hist', bins=20, title='1961')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['1962'].plot(kind='hist', bins=20, title='1962')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='1960', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='1960', y='1961', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='1961', y='1962', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='1962', y='1963', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['1960']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('1960')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['1961']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('1961')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['1962']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('1962')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['1963']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('1963')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['1960'].plot(kind='line', figsize=(8, 4), title='1960')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['1961'].plot(kind='line', figsize=(8, 4), title='1961')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['1962'].plot(kind='line', figsize=(8, 4), title='1962')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ###Fertility Data Frame

# %% [markdown]
# In order to clean and process `fertility` data frame
# Following the procedures same as above

# %%
columns_to_remove = ['Indicator Name','Indicator Code']                  # variable to store list of unnecessary columns
fertility=fertility.drop(columns=columns_to_remove)                   # dropping the unnecessary columns
fertility.rename(columns={'ï»¿"Country Name"': 'Country Name'}, inplace=True)    # renaming the column header
fertility = fertility[fertility['Country Name'] != 'Not classified']           # filtering out the specific row
fertility.columns=fertility.columns.str.lower().str.replace(' ','_')            # standardizing the column header
fertility
# Out:
#      country_name country_code  1960  1961  1962  1963  1964  1965  1966  \
# 0           Aruba          ABW  4.82  4.66  4.47  4.27  4.06  3.84  3.62
# 1     Afghanistan          AFG  7.45  7.45  7.45  7.45  7.45  7.45  7.45
# 2          Angola          AGO  7.48  7.52  7.56  7.59  7.61  7.62  7.62
# 3         Albania          ALB  6.49  6.40  6.28  6.13  5.96  5.77  5.58
# 4         Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..            ...          ...   ...   ...   ...   ...   ...   ...   ...
# 259        Kosovo          XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 260   Yemen, Rep.          YEM  7.49  7.53  7.58  7.62  7.67  7.71  7.74
# 261  South Africa          ZAF  6.04  6.03  6.01  5.99  5.96  5.92  5.88
# 262        Zambia          ZMB  7.12  7.17  7.21  7.25  7.27  7.29  7.30
# 263      Zimbabwe          ZWE  7.16  7.21  7.27  7.31  7.35  7.37  7.39
#
#      1967  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0    3.42  ...  1.76  1.76  1.77  1.78  1.78  1.79  1.80  1.80  1.80  1.80
# 1    7.45  ...  6.46  6.25  6.04  5.82  5.59  5.38  5.17  4.98  4.80  4.63
# 2    7.61  ...  6.37  6.31  6.24  6.16  6.08  6.00  5.92  5.84  5.77  5.69
# 3    5.39  ...  1.67  1.65  1.65  1.65  1.67  1.69  1.70  1.71  1.71  1.71
# 4     NaN  ...  1.18  1.25  1.19  1.27   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 259   NaN  ...  2.43  2.38  2.34  2.29  2.24  2.19  2.16  2.13  2.09  2.06
# 260  7.76  ...  5.09  4.94  4.80  4.67  4.55  4.44  4.33  4.21  4.10  4.00
# 261  5.83  ...  2.64  2.62  2.60  2.59  2.57  2.55  2.53  2.51  2.48  2.46
# 262  7.32  ...  5.64  5.56  5.48  5.40  5.32  5.24  5.17  5.10  5.04  4.98
# 263  7.40  ...  4.00  4.01  4.02  4.03  4.02  4.00  3.96  3.90  3.84  3.76
#
# [263 rows x 59 columns]
# Warning: Total number of columns (59) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# ###Expectancy Data Frame

# %% [markdown]
# Cleaning and processing `expectancy` data frame

# %%
columns_to_remove = ['Indicator Name', 'Indicator Code']           # variable to store list of unnecessary columns
expectancy = expectancy.drop(columns=columns_to_remove)            # dropping the unnecessary columns
expectancy.rename(columns={'ï»¿"Country Name"': 'Country Name'}, inplace=True)  # renaming the column header
expectancy = expectancy[expectancy['Country Name'] != 'Not classified']         # filtering out the specific row
expectancy.columns=expectancy.columns.str.lower().str.replace(' ','_')          # standardizing the column header
expectancy
# Out:
#      country_name country_code  1960  1961  1962  1963  1964  1965  1966  \
# 0           Aruba          ABW 65.66 66.07 66.44 66.79 67.11 67.44 67.76
# 1     Afghanistan          AFG 32.29 32.74 33.19 33.62 34.06 34.49 34.93
# 2          Angola          AGO 33.25 33.57 33.91 34.27 34.65 35.03 35.43
# 3         Albania          ALB 62.28 63.30 64.19 64.91 65.46 65.85 66.11
# 4         Andorra          AND   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..            ...          ...   ...   ...   ...   ...   ...   ...   ...
# 259        Kosovo          XKX   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 260   Yemen, Rep.          YEM 34.36 34.47 34.74 35.19 35.81 36.60 37.49
# 261  South Africa          ZAF 52.22 52.56 52.89 53.23 53.57 53.93 54.30
# 262        Zambia          ZMB 45.12 45.50 45.87 46.23 46.57 46.93 47.30
# 263      Zimbabwe          ZWE 51.56 51.94 52.30 52.65 52.99 53.33 53.65
#
#      1967  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0   68.09  ... 74.58 74.72 74.87 75.02 75.16 75.30 75.44 75.58 75.72 75.87
# 1   35.36  ... 59.69 60.24 60.75 61.23 61.67 62.09 62.49 62.90 63.29 63.67
# 2   35.83  ... 55.10 56.19 57.23 58.19 59.04 59.77 60.37 60.86 61.24 61.55
# 3   66.30  ... 75.66 75.94 76.28 76.65 77.03 77.39 77.70 77.96 78.17 78.34
# 4     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 259   NaN  ... 69.20 69.40 69.65 69.90 70.15 70.50 70.80 71.10 71.35 71.65
# 260 38.43  ... 62.55 62.89 63.21 63.51 63.79 64.05 64.29 64.52 64.74 64.95
# 261 54.69  ... 53.01 53.72 54.70 55.89 57.20 58.55 59.83 60.99 61.98 62.77
# 262 47.70  ... 52.31 53.75 55.19 56.59 57.87 59.01 59.98 60.77 61.40 61.87
# 263 53.97  ... 47.72 49.34 51.12 52.98 54.80 56.52 58.05 59.36 60.40 61.16
#
# [263 rows x 59 columns]

# %% [markdown]
# ###Metadata Data Frame

# %% [markdown]
# cleaning and processing `metadata` data frame

# %%
columns_to_remove = ['SpecialNotes', 'Unnamed: 5']          # variable to store list of unnecessary columns
metadata = metadata.drop(columns=columns_to_remove)         # dropping the unnecessary columns
metadata.rename(columns={'ï»¿"Country Code"': 'Country Code'}, inplace=True)    # renaming the column header
metadata.rename(columns={'IncomeGroup': 'Income Group'}, inplace=True)          # renaming the column header
metadata.rename(columns={'TableName': 'Country Name'}, inplace=True)            # renaming the column header
column_to_shift = metadata.pop(metadata.columns[3])           # shifting column 3 to 0
metadata.insert(0, column_to_shift.name, column_to_shift)
metadata.columns=metadata.columns.str.lower().str.replace(' ','_')              # standardizing the column header
metadata
# Out:
#      country_name country_code                      region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 258        Kosovo          XKX       Europe & Central Asia
# 259   Yemen, Rep.          YEM  Middle East & North Africa
# 260  South Africa          ZAF          Sub-Saharan Africa
# 261        Zambia          ZMB          Sub-Saharan Africa
# 262      Zimbabwe          ZWE          Sub-Saharan Africa
#
#             income_group
# 0            High income
# 1             Low income
# 2    Lower middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 258  Lower middle income
# 259  Lower middle income
# 260  Upper middle income
# 261  Lower middle income
# 262           Low income
#
# [263 rows x 4 columns]

# %% [markdown]
# ###Population Dataframe

# %% [markdown]
# **Merging:**<br>
# Merging `metadata` dataframe with `population` dataframe

# %%
columns_to_merge = ['country_name','region']    # listing the column headers required after merging

population_metadata = population.merge(metadata[columns_to_merge], on='country_name')    # merge at country_name
column_to_shift = population_metadata.pop(population_metadata.columns[-1])               # shifting columns
population_metadata.insert(2, column_to_shift.name, column_to_shift)

population_metadata.head()      # print the first few rows of the merged dataset
# Out:
#   country_name country_code                     region       1960       1961  \
# 0        Aruba          ABW  Latin America & Caribbean   54211.00   55438.00
# 1  Afghanistan          AFG                 South Asia 8996351.00 9166764.00
# 2       Angola          AGO         Sub-Saharan Africa 5643182.00 5753024.00
# 3      Albania          ALB      Europe & Central Asia 1608800.00 1659800.00
# 4      Andorra          AND      Europe & Central Asia   13411.00   14375.00
#
#         1962       1963       1964       1965        1966  ...        2007  \
# 0   56225.00   56695.00   57032.00   57360.00    57715.00  ...   101220.00
# 1 9345868.00 9533954.00 9731361.00 9938414.00 10152331.00  ... 26616792.00
# 2 5866061.00 5980417.00 6093321.00 6203299.00  6309770.00  ... 20997687.00
# 3 1711319.00 1762621.00 1814135.00 1864791.00  1914573.00  ...  2970017.00
# 4   15370.00   16412.00   17469.00   18549.00    19647.00  ...    82683.00
#
#          2008        2009        2010        2011        2012        2013  \
# 0   101353.00   101453.00   101669.00   102053.00   102577.00   103187.00
# 1 27294031.00 28004331.00 28803167.00 29708599.00 30696958.00 31731688.00
# 2 21759420.00 22549547.00 23369131.00 24218565.00 25096150.00 25998340.00
# 3  2947314.00  2927519.00  2913021.00  2905195.00  2900401.00  2895092.00
# 4    83861.00    84462.00    84449.00    83751.00    82431.00    80788.00
#
#          2014        2015        2016
# 0   103795.00   104341.00   104822.00
# 1 32758020.00 33736494.00 34656032.00
# 2 26920466.00 27859305.00 28813463.00
# 3  2889104.00  2880703.00  2876101.00
# 4    79223.00    78014.00    77281.00
#
# [5 rows x 60 columns]

# %% [markdown]
# **Melting:**
# <br>`population` dataframe.

# %%
melted_data_population = population_metadata.melt(id_vars=['country_name', 'country_code','region'], var_name='year', value_name='population')
sorted_data_population = melted_data_population.sort_values(by=['country_name','year']) # melting, restructuring and sorting data of population
sorted_data_population
# Out:
#       country_name country_code              region  year  population
# 1      Afghanistan          AFG          South Asia  1960  8996351.00
# 255    Afghanistan          AFG          South Asia  1961  9166764.00
# 509    Afghanistan          AFG          South Asia  1962  9345868.00
# 763    Afghanistan          AFG          South Asia  1963  9533954.00
# 1017   Afghanistan          AFG          South Asia  1964  9731361.00
# ...            ...          ...                 ...   ...         ...
# 13461     Zimbabwe          ZWE  Sub-Saharan Africa  2012 14710826.00
# 13715     Zimbabwe          ZWE  Sub-Saharan Africa  2013 15054506.00
# 13969     Zimbabwe          ZWE  Sub-Saharan Africa  2014 15411675.00
# 14223     Zimbabwe          ZWE  Sub-Saharan Africa  2015 15777451.00
# 14477     Zimbabwe          ZWE  Sub-Saharan Africa  2016 16150362.00
#
# [14478 rows x 5 columns]

# %% [markdown]
# ###Fertility Dataframe

# %%
melted_data_fertility = fertility.melt(id_vars=['country_name','country_code'], var_name='year', value_name='fertility')
sorted_data_fertility = melted_data_fertility.sort_values(by=['country_name','year'])       # melting, restructuring and sorting data of population
sorted_data_fertility
# Out:
#       country_name country_code  year  fertility
# 1      Afghanistan          AFG  1960       7.45
# 264    Afghanistan          AFG  1961       7.45
# 527    Afghanistan          AFG  1962       7.45
# 790    Afghanistan          AFG  1963       7.45
# 1053   Afghanistan          AFG  1964       7.45
# ...            ...          ...   ...        ...
# 13938     Zimbabwe          ZWE  2012       4.00
# 14201     Zimbabwe          ZWE  2013       3.96
# 14464     Zimbabwe          ZWE  2014       3.90
# 14727     Zimbabwe          ZWE  2015       3.84
# 14990     Zimbabwe          ZWE  2016       3.76
#
# [14991 rows x 4 columns]

# %% [markdown]
# **Merging:**<br>
# To merge the `sorted_data_fertility` dataframe to `sorted_data_population` dataframe:

# %%
columns_to_merge = ['fertility','country_name','year']  # listing the column headers required after merging
# merge at country_name and year
population_fertility = sorted_data_population.merge(sorted_data_fertility[columns_to_merge], on=['country_name','year'])
population_fertility
# Out:
#       country_name country_code              region  year  population  \
# 0      Afghanistan          AFG          South Asia  1960  8996351.00
# 1      Afghanistan          AFG          South Asia  1961  9166764.00
# 2      Afghanistan          AFG          South Asia  1962  9345868.00
# 3      Afghanistan          AFG          South Asia  1963  9533954.00
# 4      Afghanistan          AFG          South Asia  1964  9731361.00
# ...            ...          ...                 ...   ...         ...
# 14473     Zimbabwe          ZWE  Sub-Saharan Africa  2012 14710826.00
# 14474     Zimbabwe          ZWE  Sub-Saharan Africa  2013 15054506.00
# 14475     Zimbabwe          ZWE  Sub-Saharan Africa  2014 15411675.00
# 14476     Zimbabwe          ZWE  Sub-Saharan Africa  2015 15777451.00
# 14477     Zimbabwe          ZWE  Sub-Saharan Africa  2016 16150362.00
#
#        fertility
# 0           7.45
# 1           7.45
# 2           7.45
# 3           7.45
# 4           7.45
# ...          ...
# 14473       4.00
# 14474       3.96
# 14475       3.90
# 14476       3.84
# 14477       3.76
#
# [14478 rows x 6 columns]

# %% [markdown]
# ###Expectancy Dataframe

# %% [markdown]
# **Melting:**

# %%
melted_data_expectancy = expectancy.melt(id_vars=['country_name','country_code'], var_name='year', value_name='expectancy')
sorted_data_expectancy = melted_data_expectancy.sort_values(by=['country_name','year'])       # melting, restructuring and sorting data of population
sorted_data_expectancy
# Out:
#       country_name country_code  year  expectancy
# 1      Afghanistan          AFG  1960       32.29
# 264    Afghanistan          AFG  1961       32.74
# 527    Afghanistan          AFG  1962       33.19
# 790    Afghanistan          AFG  1963       33.62
# 1053   Afghanistan          AFG  1964       34.06
# ...            ...          ...   ...         ...
# 13938     Zimbabwe          ZWE  2012       56.52
# 14201     Zimbabwe          ZWE  2013       58.05
# 14464     Zimbabwe          ZWE  2014       59.36
# 14727     Zimbabwe          ZWE  2015       60.40
# 14990     Zimbabwe          ZWE  2016       61.16
#
# [14991 rows x 4 columns]

# %% [markdown]
# **Merging:**<br>
# Merging `sorted_data_expectancy` dataframe to `sorted_data_fertility` dataframe:

# %%
columns_to_merge = ['expectancy','country_name','year']         # listing the column headers required after merging
# merge at country_name and year
final = population_fertility.merge(sorted_data_expectancy[columns_to_merge], on=['country_name','year'])
final
# Out:
#       country_name country_code              region  year  population  \
# 0      Afghanistan          AFG          South Asia  1960  8996351.00
# 1      Afghanistan          AFG          South Asia  1961  9166764.00
# 2      Afghanistan          AFG          South Asia  1962  9345868.00
# 3      Afghanistan          AFG          South Asia  1963  9533954.00
# 4      Afghanistan          AFG          South Asia  1964  9731361.00
# ...            ...          ...                 ...   ...         ...
# 14473     Zimbabwe          ZWE  Sub-Saharan Africa  2012 14710826.00
# 14474     Zimbabwe          ZWE  Sub-Saharan Africa  2013 15054506.00
# 14475     Zimbabwe          ZWE  Sub-Saharan Africa  2014 15411675.00
# 14476     Zimbabwe          ZWE  Sub-Saharan Africa  2015 15777451.00
# 14477     Zimbabwe          ZWE  Sub-Saharan Africa  2016 16150362.00
#
#        fertility  expectancy
# 0           7.45       32.29
# 1           7.45       32.74
# 2           7.45       33.19
# 3           7.45       33.62
# 4           7.45       34.06
# ...          ...         ...
# 14473       4.00       56.52
# 14474       3.96       58.05
# 14475       3.90       59.36
# 14476       3.84       60.40
# 14477       3.76       61.16
#
# [14478 rows x 7 columns]

# %% [markdown]
# ##**Final DataFrame Process**

# %% [markdown]
# After getting the `final` dataframe, we need to still ensure that:
# *  Ensure the missing values in `'region'` which is to be dropped
# *  Round the floating numbers upto 2 decimals in certain columns for visual representation.
# * Ensuring the datatype of `"Year"` to be integer
# * Missing value of `'population'` values should be dropped.

# %%
final.dropna(subset=['region'], inplace=True)                   # replace NaN values with 'World'
final['fertility'] = final['fertility'].round(decimals=2)       # round the floating values to 2 decimals
final['expectancy'] = final['expectancy'].round(decimals=2)
final["year"] = final["year"].astype(int)                       # convert the year to integer data type
final.dropna(subset=['population'], inplace=True)               # drop missing 'population' values
final
# Out:
#       country_name country_code              region  year  population  \
# 0      Afghanistan          AFG          South Asia  1960  8996351.00
# 1      Afghanistan          AFG          South Asia  1961  9166764.00
# 2      Afghanistan          AFG          South Asia  1962  9345868.00
# 3      Afghanistan          AFG          South Asia  1963  9533954.00
# 4      Afghanistan          AFG          South Asia  1964  9731361.00
# ...            ...          ...                 ...   ...         ...
# 14473     Zimbabwe          ZWE  Sub-Saharan Africa  2012 14710826.00
# 14474     Zimbabwe          ZWE  Sub-Saharan Africa  2013 15054506.00
# 14475     Zimbabwe          ZWE  Sub-Saharan Africa  2014 15411675.00
# 14476     Zimbabwe          ZWE  Sub-Saharan Africa  2015 15777451.00
# 14477     Zimbabwe          ZWE  Sub-Saharan Africa  2016 16150362.00
#
#        fertility  expectancy
# 0           7.45       32.29
# 1           7.45       32.74
# 2           7.45       33.18
# 3           7.45       33.62
# 4           7.45       34.06
# ...          ...         ...
# 14473       4.00       56.52
# 14474       3.96       58.05
# 14475       3.90       59.36
# 14476       3.84       60.40
# 14477       3.76       61.16
#
# [12035 rows x 7 columns]

# %% [markdown]
# ##**Visual Representation**

# %% [markdown]
# ###1.1. Scatter Plot comparing Fertility Rate and Life Expectancy [Countrywise]:

# %%
# create the scatter chart using Plotly Express
fig_fertility_expectation_region = px.scatter(data_frame=final,
                 x='fertility',                    # x-axis consists of fertility rate
                 y='expectancy',                   # y-axis consists of life expectancy
                 size='population',                # bubble size based on population
                 size_max=60,                      # set the maximum size for bubbles
                 hover_name='country_name',        # will view country names on hovering
                 color='region',                   # will color accordingly to region
                 animation_frame='year',           # will animate in time frame
                 animation_group='country_name',   # animation format
                 template='plotly_white',           # black as template
                 labels={'region': 'Region'},      # standardize the label
                 range_x=[0, 10],                  # range of x axis
                 range_y=[10, 90])                 # range of y axis

fig_fertility_expectation_region.update_layout(title='Fertility Rate vs. Life Expectancy',        # title of graph
                  xaxis_title='Fertility Rate - Total [Births per Woman]',  # x label
                  yaxis_title='Life Expectancy at Birth - Total')           # y label

fig_fertility_expectation_region.show()     # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a2d4373-8c8a-43ca-ab96-73d604259901" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a2d4373-8c8a-43ca-ab96-73d604259901")) {                    Plotly.newPlot(                        "6a2d4373-8c8a-43ca-ab96-73d604259901",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=South Asia\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"ids":["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"],"legendgroup":"South Asia","marker":{"color":"#636efa","size":[8996351.0,48199747.0,223288.0,449480608.0,89887.0,10063011.0,44908293.0,9874481.0],"sizemode":"area","sizeref":382962.5,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[7.45,6.72,6.67,5.91,7.02,5.96,6.6,5.54],"xaxis":"x","y":[32.29,45.83,34.53,41.17,37.4,35.2,45.26,59.37],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Europe & Central Asia\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Andorra","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Faroe Islands","Finland","France","Georgia","Germany","Gibraltar","Greece","Greenland","Hungary","Iceland","Ireland","Isle of Man","Italy","Kazakhstan","Kosovo","Kyrgyz Republic","Latvia","Liechtenstein","Lithuania","Luxembourg","Macedonia, FYR","Moldova","Monaco","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russian Federation","San Marino","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"ids":["Albania","Andorra","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Channel Islands","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Faroe Islands","Finland","France","Georgia","Germany","Gibraltar","Greece","Greenland","Hungary","Iceland","Ireland","Isle of Man","Italy","Kazakhstan","Kosovo","Kyrgyz Republic","Latvia","Liechtenstein","Lithuania","Luxembourg","Macedonia, FYR","Moldova","Monaco","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russian Federation","San Marino","Slovak Republic","Slovenia","Spain","Sweden","Switzerland","Tajikistan","Turkey","Turkmenistan","Ukraine","United Kingdom","Uzbekistan"],"legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[1608800.0,13411.0,1874120.0,7047539.0,3895396.0,8198000.0,9153489.0,3225668.0,7867374.0,109420.0,4140000.0,572930.0,9602006.0,4579603.0,1211537.0,34661.0,4429634.0,46814237.0,3645600.0,72814900.0,23394.0,8331725.0,32500.0,9983967.0,175574.0,2828600.0,48442.0,50199700.0,9714260.0,947000.0,2172300.0,2120979.0,16495.0,2778550.0,313970.0,1488667.0,2544000.0,22452.0,480579.0,11486631.0,3581239.0,29637450.0,8857716.0,18406905.0,119897000.0,15397.0,4068095.0,1584720.0,30455000.0,7484656.0,5327827.0,2087038.0,27472331.0,1603258.0,42662149.0,52400000.0,8549493.0],"sizemode":"area","sizeref":382962.5,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[6.49,null,4.79,2.69,5.88,2.67,2.54,3.8,2.31,2.42,2.29,3.5,2.09,2.57,1.98,null,2.72,2.85,2.94,2.37,null,2.23 ...

# %% [markdown]
# ###1.2. Scatter Plot comparing Fertility Rate and Life Expectancy [Regionwise]:

# %%
# aggregating data at the region level
region_data = final.groupby(['region','year']).agg({
    'fertility': 'mean',      # calculating the mean fertility rate for each region
    'expectancy': 'mean',     # calculating the mean life expectancy for each region
    'population': 'sum'       # summing up the population for each region
}).reset_index()

# create the bubble chart for region-wise fertility, life expectancy, and population
fig_region_bubble = px.scatter(data_frame=region_data,
    x='fertility',                  # x-axis consists of fertility rate
    y='expectancy',                 # y-axis consists of life expectancy
    size='population',              # bubble size based on population
    size_max=50,                    # set the maximum size for bubbles
    hover_name='region',            # will view region on hovering
    color='region',                 # will color accordingly to region
    template='plotly_white',         # black as template
    animation_frame='year',         # will animate in time frame
    animation_group='region',       # animation format
    labels={'region': 'Region'},    # standardize the label
    range_x=[0, 10],                # range of x axis
    range_y=[10, 90]                # range of y axis
)

# Update layout and titles
fig_region_bubble.update_layout(title='Region-wise Fertility Rate vs. Life Expectancy',   # title of graph
    xaxis_title='Fertility Rate - Average [Births per Woman]',        # x label
    yaxis_title='Life Expectancy at Birth - Average')                 # y label

fig_region_bubble.show()      # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8b4ed177-0b97-4aad-80c6-9c6959c2787f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b4ed177-0b97-4aad-80c6-9c6959c2787f")) {                    Plotly.newPlot(                        "8b4ed177-0b97-4aad-80c6-9c6959c2787f",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=East Asia & Pacific\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["East Asia & Pacific"],"ids":["East Asia & Pacific"],"legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[1017908415.0],"sizemode":"area","sizeref":899940.2436,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[6.027666666666667],"xaxis":"x","y":[54.753],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Europe & Central Asia\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Europe & Central Asia"],"ids":["Europe & Central Asia"],"legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[660638384.0],"sizemode":"area","sizeref":899940.2436,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[3.327083333333333],"xaxis":"x","y":[66.35833333333333],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Latin America & Caribbean\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Latin America & Caribbean"],"ids":["Latin America & Caribbean"],"legendgroup":"Latin America & Caribbean","marker":{"color":"#00cc96","size":[220309836.0],"sizemode":"area","sizeref":899940.2436,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean","orientation":"v","showlegend":true,"x":[5.9541176470588235],"xaxis":"x","y":[57.71794117647059],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=Middle East & North Africa\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Middle East & North Africa"],"ids":["Middle East & North Africa"],"legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","size":[105488678.0],"sizemode":"area","sizeref":899940.2436,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[6.6819999999999995],"xaxis":"x","y":[49.945263157894736],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=North America\u003cbr\u003eyear=1960\u003cbr\u003efertility=%{x}\u003cbr\u003eexpectancy=%{y}\u003cbr\u003epopulation=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["North America"],"ids":["North America"],"legendgroup":"North America","marker":{"color":"#FFA15A","size":[198624409.0],"sizemode":"area","sizeref":899940.2436,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[3.73],"xaxis":"x","y":[70.44999999999999],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eRegion=South Asia\u003cbr\ ...

# %% [markdown]
# ###2. Line Chart showing Population Trends over Years:

# %%
# create the scatter chart using Plotly Express
fig_population = px.line(final,
              x='year',                                 # x-axis consists of year
              y='population',                           # y-axis consists of population
              labels={'country_name': 'Country Name'},  # standardize the label
              color='country_name',                     # will color accordingly to countries
              template='plotly_white'
              )                   # black as template

fig_population.update_layout(title='Population Trends over Years by Country',               # title of graph
                  xaxis_title='Year',                                       # x label
                  xaxis=dict(type='category'),                              # Set x-axis type to category for years
                  yaxis_title='Population - Total [in Billions]')           # y label

fig_population.show()     # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd293b7f-db86-4e87-acaa-5e662e2e3e39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd293b7f-db86-4e87-acaa-5e662e2e3e39")) {                    Plotly.newPlot(                        "cd293b7f-db86-4e87-acaa-5e662e2e3e39",                        [{"hovertemplate":"Country Name=Afghanistan\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[8996351.0,9166764.0,9345868.0,9533954.0,9731361.0,9938414.0,10152331.0,10372630.0,10604346.0,10854428.0,11126123.0,11417825.0,11721940.0,12027822.0,12321541.0,12590286.0,12840299.0,13067538.0,13237734.0,13306695.0,13248370.0,13053954.0,12749645.0,12389269.0,12047115.0,11783050.0,11601041.0,11502761.0,11540888.0,11777609.0,12249114.0,12993657.0,13981231.0,15095099.0,16172719.0,17099541.0,17822884.0,18381605.0,18863999.0,19403676.0,20093756.0,20966463.0,21979923.0,23064851.0,24118979.0,25070798.0,25893450.0,26616792.0,27294031.0,28004331.0,28803167.0,29708599.0,30696958.0,31731688.0,32758020.0,33736494.0,34656032.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Albania\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[1608800.0,1659800.0,1711319.0,1762621.0,1814135.0,1864791.0,1914573.0,1965598.0,2022272.0,2081695.0,2135479.0,2187853.0,2243126.0,2296752.0,2350124.0,2404831.0,2458526.0,2513546.0,2566266.0,2617832.0,2671997.0,2726056.0,2784278.0,2843960.0,2904429.0,2964762.0,3022635.0,3083605.0,3142336.0,3227943.0,3286542.0,3266790.0,3247039.0,3227287.0,3207536.0,3187784.0,3168033.0,3148281.0,3128530.0,3108778.0,3089027.0,3060173.0,3051010.0,3039616.0,3026939.0,3011487.0,2992547.0,2970017.0,2947314.0,2927519.0,2913021.0,2905195.0,2900401.0,2895092.0,2889104.0,2880703.0,2876101.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Algeria\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[11124888.0,11404859.0,11690153.0,11985136.0,12295970.0,12626952.0,12980267.0,13354197.0,13744387.0,14144438.0,14550034.0,14960109.0,15377093.0,15804428.0,16247113.0,16709099.0,17190239.0,17690184.0,18212326.0,18760761.0,19337715.0,19943664.0,20575701.0,21228289.0,21893853.0,22565905.0,23241272.0,23917897.0,24591492.0,25257672.0,25912367.0,26554329.0,27181094.0,27786259.0,28362253.0,28904298.0,29411415.0,29886 ...

# %% [markdown]
# ###3. Population Comparison Among Regions

# %%
# grouping the data by region to get the sum of population
region_population = final.groupby('region')['population'].sum().reset_index()

# create the bar chart using Plotly Express
fig_region_population = px.bar(region_population,
                               x='region',                    # x-axis consists of region
                               y='population',                # y-axis consists of population
                               template='plotly_white',        # black as template
                               labels={'region': 'Region'},   # standardize the label
                               color='region')                # will color accordingly to region

fig_region_population.update_layout(title='Population Comparison Among Regions',      # title of graph
                  xaxis_title='Region',                                               # x label
                  yaxis_title='Population - Total [in Billions]')                     # y label

fig_region_population.show()    # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f412866-f935-463e-85d3-9e91de4efa79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f412866-f935-463e-85d3-9e91de4efa79")) {                    Plotly.newPlot(                        "4f412866-f935-463e-85d3-9e91de4efa79",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[96354009368.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[46157829848.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean","offsetgroup":"Latin America & Caribbean","orientation":"v","showlegend":true,"textposition":"auto","x":["Latin America & Caribb
# %% [markdown]
# ###5. Population of Each Region Over Years

# %%
# grouping the data by region and year to get the sum of population for each region per year
region_population = final.groupby(['region', 'year'])['population'].sum().reset_index()

# creating the area chart using Plotly Express
fig_region_population_line = px.area(region_population,
              x='year',                                       # x-axis consists of year
              y='population',                                 # y-axis consists of population
              color='region',                                 # will color accordingly to region
              line_group='region',
              labels={'region': 'Region'},                    # standardize the label
              template='plotly_white')                         # black as template

fig_region_population_line.update_layout(title='Population of Each Region Over Years',      # title of graph
                  xaxis=dict(type='category'),                                              # Set x-axis type to category for years
                  xaxis_title='Year',                                                       # x label
                  yaxis_title='Population - Total [in Billions]')                           # y label

fig_region_population_line.show()   # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="03ce9696-f69d-4bd5-861c-2f71c316bb69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03ce9696-f69d-4bd5-861c-2f71c316bb69")) {                    Plotly.newPlot(                        "03ce9696-f69d-4bd5-861c-2f71c316bb69",                        [{"fillpattern":{"shape":""},"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"stackgroup":"1","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[1017908415.0,1020859551.0,1034721686.0,1059889834.0,1084668163.0,1110453368.0,1139613643.0,1167777031.0,1196310105.0,1228326166.0,1260338559.0,1293298631.0,1324445261.0,1354032262.0,1383468435.0,1409966287.0,1433581976.0,1455905286.0,1478170060.0,1500848931.0,1523065642.0,1546106061.0,1571426407.0,1596734990.0,1620791622.0,1645437014.0,1671658078.0,1699280678.0,1727159677.0,1754409402.0,1780946394.0,1806467089.0,1830253862.0,1853191809.0,1876167311.0,1898788502.0,1921080514.0,1942830222.0,1963766813.0,1983353333.0,2002037145.0,2020048907.0,2037153667.0,2053444067.0,2069180268.0,2084727909.0,2100144359.0,2114982109.0,2130088267.0,2144809931.0,2159425292.0,2174031936.0,2188966727.0,2203980396.0,2219236953.0,2234401756.0,2249850609.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"stackgroup":"1","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[660638384.0,668317972.0,676242669.0,684230675.0,692140664.0,699815007.0,706500112.0,712999789.0,719246895.0,725372863.0,730976178.0,736594439.0,742762857.0,748776961.0,754573324.0,760169578.0,765624318.0,770836845.0,776001994.0,781193199.0,786575090.0,791810272.0,796532967.0,801056728.0,805792381.0,810642882.0,815619058.0,820655790.0,825743236.0,830881813.0,842848473.0,846178276.0,849656745.0,852762016.0,854723055.0,856352860.0,857652705.0,859112733.0,860236341.0,861380108.0,862304086.0,863615632.0,865196877.0,867457664.0,870030756.0,872661616.0,875343235.0,878465990.0,881965815.0,885591693.0,889016216.0,891094963.0,894666668.0,898855116.0,903094669.5,907393322.0,911847278.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Region=Latin America & Caribbean\u003cbr\u003eyear=%{x}\u003cbr\u003epopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean","orientation":"v","showlegend":true,"stackgroup":"1","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,20 ...

# %% [markdown]
# ###6. Life Expectancy of Each Region Over Years

# %%
# grouping the data by region and year to get the average life expectancy for each region per year
region_life_expectancy = final.groupby(['region', 'year'])['expectancy'].mean().reset_index()

# creating the area chart using Plotly Express
fig_region_life_expectancy = px.area(region_life_expectancy,
                                     x='year',                          # x-axis consists of year
                                     y='expectancy',                    # y-axis consists of life expectancy
                                     color='region',                    # will color accordingly to region
                                     labels={'region': 'Region'},       # standardize the label
                                     template='plotly_white')            # black as template

fig_region_life_expectancy.update_layout(title='Life Expectancy of Each Region Over Years',      # title of graph
                  xaxis=dict(type='category'),                                                   # Set x-axis type to category for years
                  xaxis_title='Year',                                                            # x label
                  yaxis_title='Life Expectancy [in Years]')                                      # y label

fig_region_life_expectancy.show()   # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b68c8013-983f-461e-8910-735f05fb381a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b68c8013-983f-461e-8910-735f05fb381a")) {                    Plotly.newPlot(                        "b68c8013-983f-461e-8910-735f05fb381a",                        [{"fillpattern":{"shape":""},"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eyear=%{x}\u003cbr\u003eexpectancy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"stackgroup":"1","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[54.753,55.221,55.69666666666667,56.20366666666666,56.69866666666667,57.181666666666665,57.68333333333333,58.17333333333333,58.617,59.051,59.44866666666667,59.783,60.04333333333333,60.26,60.46966666666666,60.69566666666666,60.908,61.21366666666667,61.605333333333334,62.05433333333334,62.58133333333333,63.18033333333333,63.733666666666664,64.278,64.76333333333334,65.19,65.57233333333333,66.11258064516129,66.209,66.50333333333333,66.93612903225807,67.191,67.50866666666667,67.824,68.11133333333333,68.53290322580645,68.777,69.117,69.53266666666667,69.74645161290321,70.0828125,70.55966666666667,70.87966666666667,71.20800000000001,71.55266666666667,71.77354838709678,72.19566666666667,72.48666666666666,72.758,73.051,73.28299999999999,73.49133333333334,73.73266666666667,73.959,74.16466666666666,74.361,74.51933333333334],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eyear=%{x}\u003cbr\u003eexpectancy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"stackgroup":"1","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[66.35833333333333,66.764375,66.87270833333334,67.188125,67.62020833333334,67.80458333333333,68.06458333333333,68.255,68.3975,68.46791666666667,68.74125,68.90625,69.17625,69.45367346938775,69.55229166666668,69.69229166666666,69.88833333333334,70.10229166666666,70.1862,70.23428571428572,70.3565306122449,70.47279999999999,70.70859999999999,70.8014,71.028,71.184,71.58980392156863,71.76098039215687,71.87039215686275,71.99352941176471,72.00450980392156,72.01634615384616,72.09137254901961,72.00823529411765,72.29301886792453,72.28596153846154,72.60615384615384,72.82849056603773,73.08846153846153,73.31980769230769,73.51622641509434,73.8666037735849,74.09185185185186,74.20471698113208,74.59754716981132,74.72415094339622,74.99698113207548,75.22584905660376,75.56754716981132,75.86188679245282,76.13849056603775,76.55245283018868,76.91648148148148,77.03132075471697,77.43076923076923,77.46019230769231,77.56307692307692],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Region=Latin America & Caribbean\u003cbr\u003eyear=%{x}\u003cbr\u003eexpectancy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin Americ ...

# %% [markdown]
# ###7. Fertility Rate of Each Region Over Years

# %%
# grouping the data by region and year to get the average fertility rate for each region per year
region_fertility = final.groupby(['region', 'year'])['fertility'].mean().reset_index()

# creating the area chart using Plotly Express
fig_region_fertility = px.area(region_fertility,
                               x='year',                            # x-axis consists of year
                               y='fertility',                       # y-axis consists of fertility rate
                               color='region',                      # will color accordingly to region
                               labels={'region': 'Region'},         # standardize the label
                               template='plotly_white')              # black as template

fig_region_fertility.update_layout(title='Fertility Rate of Each Region Over Years',      # title of graph
                  xaxis=dict(type='category'),                                      # Set x-axis type to category for years
                  xaxis_title='Year',                                               # x label
                  yaxis_title='Fertility Rate [Births per Woman]')                  # y label

fig_region_fertility.show()     # show the plot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry Name=Afghanistan\u003cbr\u003epopulation=%{marker.size}\u003cbr\u003ecountry_code=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan"],"legendgroup":"Afghanistan","locations":["AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG","AFG"],"marker":{"color":"#636efa","size":[8996351.0,9166764.0,9345868.0,9533954.0,9731361.0,9938414.0,10152331.0,10372630.0,10604346.0,10854428.0,11126123.0,11417825.0,11721940.0,12027822.0,12321541.0,12590286.0,12840299.0,13067538.0,13237734.0,13306695.0,13248370.0,13053954.0,12749645.0,12389269.0,12047115.0,11783050.0,11601041.0,11502761.0,11540888.0,11777609.0,12249114.0,12993657.0,13981231.0,15095099.0,16172719.0,17099541.0,17822884.0,18381605.0,18863999.0,19403676.0,20093756.0,20966463.0,21979923.0,23064851.0,24118979.0,25070798.0,25893450.0,26616792.0,27294031.0,28004331.0,28803167.0,29708599.0,30696958.0,31731688.0,32758020.0,33736494.0,34656032.0],"sizemode":"area","sizeref":3446662.5,"symbol":"circle"},"mode":"markers","name":"Afghanistan","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry Name=Albania\u003cbr\u003epopulation=%{marker.size}\u003cbr\u003ecountry_code=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania"],"legendgroup":"Albania","locations":["ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB","ALB" ...

# %% [markdown]
# ###9. Correlation Analysis

# %%
import plotly.figure_factory as ff          # import special library for heatmap i.e figure_factory
correlation_matrix = final.corr()           # calculates the correlation matrix using the .corr()

# create a heatmap using Plotly
fig_heatmap = ff.create_annotated_heatmap(
    z=correlation_matrix.values,                          # calculating correlation values
    x=list(correlation_matrix.columns),                   # listing the matrix columns
    y=list(correlation_matrix.index),                     # listing the matrix index
    colorscale='Reds',                                   # color gradient
    annotation_text=correlation_matrix.round(2).values    # we need to round off in order to avoud long series of decimals
)

fig_heatmap.update_layout(title='Correlation Analysis Heatmap')   # title of the plot
fig_heatmap.show()       # show the plot
# Out:
# <ipython-input-52-733a19ebbbae>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fc70a1cb-4486-42e3-8c1f-f811fa349520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc70a1cb-4486-42e3-8c1f-f811fa349520")) {                    Plotly.newPlot(                        "fc70a1cb-4486-42e3-8c1f-f811fa349520",                        [{"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"reversescale":false,"showscale":false,"x":["year","population","fertility","expectancy"],"y":["year","population","fertility","expectancy"],"z":[[1.0,0.06045634072482187,-0.45644530468706884,0.44762011805440177],[0.06045634072482187,1.0,-0.08508442681907114,0.033682219917673784],[-0.45644530468706884,-0.08508442681907114,1.0,-0.8488048361200391],[0.44762011805440177,0.033682219917673784,-0.8488048361200391,1.0]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"year","xref":"x","y":"year","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.06","x":"population","xref":"x","y":"year","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.46","x":"fertility","xref":"x","y":"year","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.45","x":"expectancy","xref":"x","y":"year","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.06","x":"year","xref":"x","y":"population","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"population","xref":"x","y":"population","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.09","x":"fertility","xref":"x","y":"population","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.03","x":"expectancy","xref":"x","y":"population","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.46","x":"year","xref":"x","y":"fertility","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.09","x":"population","xref":"x","y":"fertility","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"fertility","xref":"x","y":"fertility","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.85","x":"expectancy","xref":"x","y":"fertility","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.45","x":"year","xref":"x","y":"expectancy","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0.03","x":"population","xref":"x","y":"expectancy","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"-0.85","x":"fertility","xref":"x","y":"expectancy","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"1.0","x":"expectancy","xref":"x","y":"expectancy","yref":"y"}],"xaxis":{"dtick":1,"gridcolor":"rgb(0, 0, 0)","side":"top","ticks":""},"yaxis":{"dtick":1,"ticks":"","ticksuffix":"  "},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...

# %% [markdown]
# <br>**The End**<br>
